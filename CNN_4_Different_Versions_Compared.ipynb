# %%
#4 different versions of faces were compared.


import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,Activation,Flatten, Conv2D, MaxPooling2D
import pickle
import cv2
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from keras.utils.vis_utils import plot_model
from sklearn.metrics import classification_report
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
# f = open("Gaussian_Results.txt", "a")

test_accuracy_lemniscate = []
for _ in range(0,5,1):

    X = pickle.load(open("D:\\Anaconda\\envs\\TensorGPU\\Emma_Gal_Face_Research\\X_Train_Lemniscate.pickle","rb"))
    y = pickle.load(open("D:\\Anaconda\\envs\\TensorGPU\\Emma_Gal_Face_Research\\Y_Train_Lemniscate.pickle","rb"))
    X = X/255.0
    CATEGORIES = ["Emma","Gal"]

    X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                        test_size=.3,
                                                        random_state=42)
    model = Sequential()
    model.add(Conv2D(64,(3,3),input_shape = X.shape[1:]))
    model.add(Activation("relu"))
#     model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Conv2D(64,(3,3)))
    model.add(Activation("relu"))
    model.add(MaxPooling2D(pool_size=(2,2)))
    
    


    model.add(Flatten())
    model.add(Dense(64))
    model.add(Activation("relu"))
    model.add(Dense(1))
    model.add(Activation("sigmoid"))
    # plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
    model.compile(loss = "binary_crossentropy",
                 optimizer = "adam",
                 metrics=["accuracy"])


    history = model.fit(X_train,y_train,batch_size=32,epochs = 10,validation_split=0.2, verbose = 0)

    y_pred = model.predict(X_test, batch_size=32, verbose=0)
    y_pred_bool = np.argmax(y_pred, axis=1)

#     print(classification_report(y_test, y_pred_bool))

    score = model.evaluate(X_test, y_test, verbose=0)
#     f.write(f'Test loss: {score[0]} / Test accuracy: {score[1]}')
    test_accuracy_lemniscate.append(score[1])
#     f.write('\n')
    print(f'Test loss: {score[0]} / Test accuracy: {score[1]}')

# Visualize history
# Plot history: Loss
# plt.plot(history.history['val_loss'])
# plt.title('Validation loss history')
# plt.ylabel('Loss value')
# plt.xlabel('No. epoch')
# plt.show()

# # Plot history: Accuracy
# plt.plot(history.history['val_acc'])
# plt.title('Validation accuracy history')
# plt.ylabel('Accuracy value (%)')
# plt.xlabel('No. epoch')
# plt.show()

# f.close()
# Out:
# WARNING:tensorflow:From D:\Anaconda\envs\TensorGPU\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From D:\Anaconda\envs\TensorGPU\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Test loss: 0.2024436896694325 / Test accuracy: 0.9626375436782837
# Test loss: 0.23222881602658035 / Test accuracy: 0.9560703039169312
# Test loss: 0.192779341337571 / Test accuracy: 0.9628150463104248
# Test loss: 0.19707675191934254 / Test accuracy: 0.9681398868560791
# Test loss: 0.27027085332395323 / Test accuracy: 0.9492367506027222

# %%
# # f = open("D:\\Anaconda\\envs\\TensorGPU\\Facial_Expression_Research\\CK+48\\Balanced_Dataset\\Filters_Applied_Contourlet_Fusioned\\Contourlet_Results.txt", "a")
# test_accuracy_contourlet = []
# for _ in range(0,5,1):

#     X = pickle.load(open("D:\\Anaconda\\envs\\TensorGPU\\Emma_Gal_Face_Research\\X_Train_Contourlet.pickle","rb"))
#     y = pickle.load(open("D:\\Anaconda\\envs\\TensorGPU\\Emma_Gal_Face_Research\\Y_Train_Contourlet.pickle","rb"))
#     X = X/255.0
#     CATEGORIES = ["Emma","Gal"]
    
#     X_train, X_test, y_train, y_test = train_test_split(X, y,
#                                                         test_size=.3,
#                                                         random_state=42)
#     model = Sequential()
#     model.add(Conv2D(64,(3,3),input_shape = X.shape[1:]))
#     model.add(Activation("relu"))
#     model.add(MaxPooling2D(pool_size=(2,2)))

#     model.add(Conv2D(64,(3,3)))
#     model.add(Activation("relu"))
#     model.add(MaxPooling2D(pool_size=(2,2)))
    
    

    
#     model.add(Flatten())
#     model.add(Dense(64))
#     model.add(Activation("relu"))
#     model.add(Dense(1))
#     model.add(Activation("sigmoid"))
#     # plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
#     model.compile(loss = "binary_crossentropy",
#                  optimizer = "adam",
#                  metrics=["accuracy"])


#     history = model.fit(X_train,y_train,batch_size=32,epochs = 10,validation_split=0.2, verbose = 0)

#     y_pred = model.predict(X_test, batch_size=32, verbose=0)
#     y_pred_bool = np.argmax(y_pred, axis=1)

# #     print(classification_report(y_test, y_pred_bool))

#     score = model.evaluate(X_test, y_test, verbose=0)
# #     f.write(f'Test loss: {score[0]} / Test accuracy: {score[1]}')
#     test_accuracy_contourlet.append(score[1])
# #     f.write('\n')
#     print(f'Test loss: {score[0]} / Test accuracy: {score[1]}')

# # Visualize history
# # Plot history: Loss

# # plt.plot(history.history['val_loss'])
# # plt.title('Validation loss history')
# # plt.ylabel('Loss value')
# # plt.xlabel('No. epoch')
# # plt.show()

# # # Plot history: Accuracy
# # plt.plot(history.history['val_acc'])
# # plt.title('Validation accuracy history')
# # plt.ylabel('Accuracy value (%)')
# # plt.xlabel('No. epoch')
# # plt.show()
# # f.close()

# %%
# # f = open("D:\\Anaconda\\envs\\TensorGPU\\Facial_Expression_Research\\CK+48\\Balanced_Dataset\\Filters_Applied_Gabor\\Gabor_Results.txt","a")
# test_accuracy_gabor = []
# for _ in range(0,5,1):
#     X = pickle.load(open("D:\\Anaconda\\envs\\TensorGPU\\Emma_Gal_Face_Research\\X_Train_Gabor.pickle","rb"))
#     y = pickle.load(open("D:\\Anaconda\\envs\\TensorGPU\\Emma_Gal_Face_Research\\Y_Train_Gabor.pickle","rb"))
#     X = X/255.0
#     CATEGORIES = ["Emma","Gal"]
    
#     X_train, X_test, y_train, y_test = train_test_split(X, y,
#                                                         test_size=.3,
#                                                         random_state=42)

#     model = Sequential()
#     model.add(Conv2D(64,(3,3),input_shape = X.shape[1:]))
#     model.add(Activation("relu"))
#     model.add(MaxPooling2D(pool_size=(2,2)))

#     model.add(Conv2D(64,(3,3)))
#     model.add(Activation("relu"))
#     model.add(MaxPooling2D(pool_size=(2,2)))
    
    

    
#     model.add(Flatten())
#     model.add(Dense(64))
#     model.add(Activation("relu"))
#     model.add(Dense(1))
#     model.add(Activation("sigmoid"))
#     # plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
#     model.compile(loss = "binary_crossentropy",
#                  optimizer = "adam",
#                  metrics=["accuracy"])




#     history = model.fit(X_train,y_train,batch_size=32,epochs = 10,validation_split=0.2,verbose = 0)

#     y_pred = model.predict(X_test, batch_size=32, verbose=0)
#     y_pred_bool = np.argmax(y_pred, axis=1)

# #     print(classification_report(y_test, y_pred_bool))

#     score = model.evaluate(X_test, y_test, verbose=0)
# #     f.write(f'Test loss: {score[0]} / Test accuracy: {score[1]}')
#     test_accuracy_gabor.append(score[1])
# #     f.write('\n')
#     print(f'Test loss: {score[0]} / Test accuracy: {score[1]}')

# # Visualize history
# # Plot history: Loss
# # plt.plot(history.history['val_loss'])
# # plt.title('Validation loss history')
# # plt.ylabel('Loss value')
# # plt.xlabel('No. epoch')
# # plt.show()

# # # Plot history: Accuracy
# # plt.plot(history.history['val_acc'])
# # plt.title('Validation accuracy history')
# # plt.ylabel('Accuracy value (%)')
# # plt.xlabel('No. epoch')
# # plt.show()
# # f.close()

# %%
# f = open("D:\\Anaconda\\envs\\TensorGPU\\Facial_Expression_Research\\CK+48\\Balanced_Dataset\\Filters_Applied_Gabor\\Gabor_Results.txt","a")
test_accuracy_normal = []
for _ in range(0,5,1):
    X = pickle.load(open("D:\\Anaconda\\envs\\TensorGPU\\Emma_Gal_Face_Research\\X_Train_Normal.pickle","rb"))
    y = pickle.load(open("D:\\Anaconda\\envs\\TensorGPU\\Emma_Gal_Face_Research\\Y_Train_Normal.pickle","rb"))
    X = X/255.0
    CATEGORIES = ["Emma","Gal"]
    
    X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                        test_size=.3,
                                                        random_state=42)

    model = Sequential()
    model.add(Conv2D(64,(3,3),input_shape = X.shape[1:]))
    model.add(Activation("relu"))
#     model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Conv2D(64,(3,3)))
    model.add(Activation("relu"))
    model.add(MaxPooling2D(pool_size=(2,2)))
    
    

    
    model.add(Flatten())
    model.add(Dense(64))
    model.add(Activation("relu"))
    model.add(Dense(1))
    model.add(Activation("sigmoid"))
    # plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
    model.compile(loss = "binary_crossentropy",
                 optimizer = "adam",
                 metrics=["accuracy"])




    history = model.fit(X_train,y_train,batch_size=32,epochs = 10,validation_split=0.2,verbose = 0)

    y_pred = model.predict(X_test, batch_size=32, verbose=0)
    y_pred_bool = np.argmax(y_pred, axis=1)

#     print(classification_report(y_test, y_pred_bool))

    score = model.evaluate(X_test, y_test, verbose=0)
#     f.write(f'Test loss: {score[0]} / Test accuracy: {score[1]}')
    test_accuracy_normal.append(score[1])
#     f.write('\n')
    print(f'Test loss: {score[0]} / Test accuracy: {score[1]}')

# Visualize history
# Plot history: Loss
# plt.plot(history.history['val_loss'])
# plt.title('Validation loss history')
# plt.ylabel('Loss value')
# plt.xlabel('No. epoch')
# plt.show()

# # Plot history: Accuracy
# plt.plot(history.history['val_acc'])
# plt.title('Validation accuracy history')
# plt.ylabel('Accuracy value (%)')
# plt.xlabel('No. epoch')
# plt.show()
# f.close()
# Out:
# Test loss: 0.10353802444752508 / Test accuracy: 0.9779907464981079
# Test loss: 0.10199292212569135 / Test accuracy: 0.9783457517623901
# Test loss: 0.1105379974742914 / Test accuracy: 0.9772807955741882
# Test loss: 0.08927838175821855 / Test accuracy: 0.9779907464981079
# Test loss: 0.10119021054306088 / Test accuracy: 0.976925790309906

# %%
print(sum(test_accuracy_normal) / len(test_accuracy_normal))
# print(sum(test_accuracy_gabor) / len(test_accuracy_gabor))
# print(sum(test_accuracy_contourlet) / len(test_accuracy_contourlet))
print(sum(test_accuracy_lemniscate) / len(test_accuracy_lemniscate))
# Out:
# 0.9773517847061157
# 0.9380546689033509
# 0.9224174737930297
# 0.9640397548675537

# %%
0.7004484355449676
0.7439461946487427
0.8636771321296692

0.6668161392211914
0.7118834018707275
0.8446188330650329

0.6991031408309937
0.7479820609092712
0.8603138983249664
